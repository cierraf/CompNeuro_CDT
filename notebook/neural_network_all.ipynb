# %% [markdown]
# # 1.Package Import

# %%
from bmovie_code import gen_table1_subj_info
from pynwb import NWBHDF5IO
from pathlib import Path
import numpy as np
import pandas as pd

from new_code import data_summary, load_data_into_pds, load_data_into_dict, slicer, label, feature, decompose, fusion, new_fusion
from new_code.neural_network import dataset_builder, Trainer, full_model
from new_code.neural_network.evaluation import metrics

import pickle
from scipy.signal import detrend

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch

print("MPS:", torch.backends.mps.is_available())
print("CUDA:", torch.cuda.is_available())

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)
# Out:
# MPS: True
# CUDA: False
# Using device: mps

# %% [markdown]
# # 2. Global file location (need to specify your own path)

# %%
NWB_DIR="/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files"
BIDS_DIR="/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/bids_files"

# %%
gen_table1_subj_info.main(
    nwb_input_dir=NWB_DIR,
    bids_datadir=BIDS_DIR
)

# %% [markdown]
# # 3. Load labels and data

# %%
# labels
with open("../assets/annotations/short_faceannots.pkl", "rb") as f:
    face_annots = pickle.load(f)

type(face_annots)
# print(list(face_annots.items())[:10])

path = "../assets/annotations/scenecut_info.csv"
scenecut_info = pd.read_csv(path)

print(scenecut_info.head())
# Out:
#    scene_id  shot_start_fr  shot_start_t  shot_dur_t  location cut_type  \
# 0       1.0            1.0          0.00        4.72  backyard      cut
# 1       1.0          119.0          4.72       10.28  backyard      cut
# 2       1.0          376.0         15.00        1.72  backyard      cut
# 3       1.0          419.0         16.72        2.36  backyard      cut
# 4       1.0          478.0         19.08        2.64  backyard      cut
#
#    cut_dur_t  cut_dur_fr
# 0        0.0           0
# 1        0.0           0
# 2        0.0           0
# 3        0.0           0
# 4        0.0           0

# %%
df_face_note = label.build_face_feature_df(face_annots, target_id="Jacky")
print(df_face_note.tail())
# Out:
#         frame_key  frame_idx  movie_time  n_faces  total_face_area  \
# 9373  frame_11898      11898      475.92        2      35470.00073
# 9374  frame_11899      11899      475.96        2      35470.00073
# 9375  frame_11900      11900      476.00        2      35470.00073
# 9376  frame_11901      11901      476.04        2      35470.00073
# 9377  frame_11902      11902      476.08        2      35470.00073
#
#       max_face_area  Jacky_present  any_front_face dominant_emotion  \
# 9373   24058.686485              0               1        surprised
# 9374   24058.686485              0               1        surprised
# 9375   24058.686485              0               1        surprised
# 9376   24058.686485              0               1        surprised
# 9377   24058.686485              0               1        surprised
#
#       emo_afraid  emo_angry  emo_happy  emo_neutral  emo_surprised
# 9373       False      False      False        False           True
# 9374       False      False      False        False           True
# 9375       False      False      False        False           True
# 9376       False      False      False        False           True
# 9377       False      False      False        False           True

# %% [markdown]
# ## 3.1 Label Check

# %%
import matplotlib.pyplot as plt

emo_cols = [
    "emo_afraid",
    "emo_angry",
    "emo_happy",
    "emo_neutral",
    "emo_surprised"
]

t = df_face_note["movie_time"].values

# ===================================
# face emotion label check
# ===================================
plt.figure(figsize=(6, 3))

for i, col in enumerate(emo_cols):
    y = df_face_note[col].astype(int) * (i + 1)
    plt.scatter(t, y, s=5, label=col)

plt.axvline(0, color="black", linestyle="--")
plt.yticks(range(1, len(emo_cols)+1), emo_cols)
plt.ylim(0.5, len(emo_cols)+0.5)
plt.xlabel("Time (s)")
plt.title("Emotion labels over time")
plt.legend(bbox_to_anchor=(1.0,0), loc="lower left", frameon=False)
plt.show()

# ===================================
# face emotion switching
# ===================================
is_non_neutral = ~df_face_note["emo_neutral"]

plt.figure(figsize=(6, 3))
plt.plot(t, is_non_neutral.astype(int), linewidth=1)

plt.xlabel("Time (s)")
plt.ylabel("Non-neutral (1)")
plt.title("Neutral vs Non-neutral switching")
plt.ylim(-0.1, 1.1)
plt.show()

# ===================================
# distribution check
# ===================================
labels = df_face_note["dominant_emotion"].values

segments = []
start = 0

for i in range(1, len(labels)):
    if labels[i] != labels[i-1]:
        segments.append((labels[i-1], start, i-1))
        start = i

segments.append((labels[-1], start, len(labels)-1))

lengths = [end - start + 1 for (_, start, end) in segments]

plt.figure(figsize=(6, 3))
plt.hist(lengths, bins=50)
plt.xlabel("Segment length (frames)")
plt.ylabel("Count")
plt.title("Distribution of label segment length")
plt.show()

print("median:", np.median(lengths))
print("short (<5 frames):", np.mean(np.array(lengths) < 5))

# ===================================
# screen check
# ===================================

lengths = np.array(lengths)

thresholds = np.arange(1, 30)
proportion = [(lengths >= th).mean() for th in thresholds]

plt.figure(figsize=(6, 3))
plt.plot(thresholds, proportion)
plt.xlabel("Min segment length (frames)")
plt.ylabel("Proportion kept")
plt.title("Data retained vs segment length threshold")
plt.show()
# Out:
# median: 47.0
# short (<5 frames): 0.0

# %%
import matplotlib.pyplot as plt

t = df_face_note["movie_time"].values

jacky = df_face_note["Jacky_present"].astype(int).values
front = df_face_note["any_front_face"].astype(int).values

plt.figure(figsize=(6, 2))

plt.scatter(t[jacky == 1], [1]*np.sum(jacky==1), s=2, label="Jacky_present")
plt.scatter(t[front == 1], [0]*np.sum(front==1), s=2, label="any_front_face")

plt.yticks([0, 1], ["Front Face", "Jacky"])
plt.xlabel("Time (s)")
plt.title("Face presence raster")
plt.legend(bbox_to_anchor=(1.0,0), loc="lower left", frameon=False)
plt.show()

# %%
nwb_path = load_data_into_pds.find_nwb_file_for_subject(NWB_DIR, "CS41")
print("Using:", nwb_path)

io = NWBHDF5IO(str(nwb_path), "r", load_namespaces=True)
nwb = io.read()

print("\n=== acquisition keys ===")
print(list(nwb.acquisition.keys()))

print("\n=== processing modules ===")
print(list(nwb.processing.keys()))

for mod_name, mod in nwb.processing.items():
    print(f"\n=== processing[{mod_name}] ===")

    for di_name, di in mod.data_interfaces.items():
        print(f"\n--- data_interface: {di_name} ({type(di)}) ---")

        # 情况1：BehavioralTimeSeries / EyeTracking / PupilTracking
        if hasattr(di, "time_series"):
            for ts_name, ts in di.time_series.items():
                data = ts.data
                print(f"  TimeSeries: {ts_name}")
                print(f"    shape: {data.shape}")
                print(f"    dtype: {data.dtype}")

        # 情况2：直接就是 TimeSeries
        elif hasattr(di, "data"):
            data = di.data
            print(f"  direct data:")
            print(f"    shape: {data.shape}")
            print(f"    dtype: {data.dtype}")

        else:
            print("  Unknown structure")

print("\n=== stimulus keys ===")
print(list(getattr(nwb, "stimulus", {}).keys()))

print("\n=== intervals ===")
print(list(getattr(nwb, "intervals", {}).keys()))

io.close()
# Out:
# Using: /Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS41/sub-CS41_ses-P41CSR1_behavior+ecephys.nwb
#
# === acquisition keys ===
# ['events_ttl', 'experiment_ids']
#
# === processing modules ===
# ['behavior', 'ecephys']
#
# === processing[behavior] ===
#
# --- data_interface: Blink (<class 'pynwb.behavior.BehavioralTimeSeries'>) ---
#   TimeSeries: TimeSeries
#     shape: (168,)
#     dtype: float64
#
# --- data_interface: EyeTracking (<class 'pynwb.behavior.EyeTracking'>) ---
#   Unknown structure
#
# --- data_interface: Fixation (<class 'pynwb.behavior.BehavioralTimeSeries'>) ---
#   TimeSeries: TimeSeries
#     shape: (1577, 4)
#     dtype: float64
#
# --- data_interface: PupilTracking (<class 'pynwb.behavior.PupilTracking'>) ---
#   TimeSeries: TimeSeries
#     shape: (374801,)
#     dtype: int64
#
# --- data_interface: Saccade (<class 'pynwb.behavior.BehavioralTimeSeries'>) ---
#   TimeSeries: TimeSeries
#     shape: (1577, 7)
#     dtype: float64
#
# === processing[ecephys] ===
#
# --- data_interface: LFP_macro (<class 'pynwb.ecephys.LFP'>) ---
#   Unknown structure
#
# --- data_interface: LFP_micro (<class 'pynwb.ecephys.LFP'>) ---
#   Unknown structure
#
# === stimulus keys ===
# ['movieframe_time']
#
# === intervals ===
# ['trials']

# %%
# sub_nums = [41,]
sub_nums = [41, 42, 43, 44, 47, 48, 49, 51, 53, 54, 55, 56, 57, 58, 60, 62]

filter_config = {
    "lfp_macro": [
        {"type": "bandstop", "low": 58, "high": 62, "order": 4},
        {"type": "bandstop", "low": 118, "high": 122, "order": 4},
        {"type": "bandpass", "low": 0.5, "high": 150, "order": 4},
    ],
    "lfp_micro": [
        {"type": "bandstop", "low": 58, "high": 62, "order": 4},
        {"type": "bandstop", "low": 118, "high": 122, "order": 4},
        {"type": "bandpass", "low": 0.5, "high": 150, "order": 4},
    ],
    "eye_gaze":  {"type": "lowpass",  "high": 20.0, "order": 4},
    "pupil":     {"type": "lowpass",  "high": 10.0, "order": 4},
}

data = load_data_into_dict.load_multimodal_subjects_movie_aligned(
    sub_nums=sub_nums,
    nwb_root=NWB_DIR,
    bids_root=BIDS_DIR,
    max_nwb_samples=2000000,
    b_filter_data=True,
    filter_config=filter_config,
    
    grid_source= "uniform",   # {"movie_frame_time", "uniform", "lfp_raw"}
    grid_dt = 0.004,         # used when grid_source == "uniform"
    uniform_grid_include_baseline = True,

    compute_firing_rate= True,
    firing_rate_bin_width= None,  # if None, infer from t_grid
    compute_lfp_bandpower= True,
    lfp_bandpower_on_raw= True,       # recommended
    bands= None,

    # optional fmri
    load_fmri= False,
    fmri_max_runs= None,
)

print(data[41].keys())
print(data[41]['meta'])
print(data[41]["lfp_macro"].shape, data[41]["eye_gaze"].shape)
# print("n_units:", data[41]["meta"]["n_units"], "firing_rate:", data[41]["firing_rate"].shape)
print("band keys:", list(data[41]["lfp_bandpower"].keys()))
# data[41]["lfp_macro"][:, :5]
x = data[41]["lfp_macro"]
t = data[41]["time_grid"]
print(x.shape, len(t))
# Out:
# [sub 41] t_eye_raw range=(0.000, 749.600)
# [sub 41] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS41/sub-CS41_ses-P41CSR1_behavior+ecephys.nwb
# [sub 41] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 41] t_macro_movie range=(-10.000, 753.963)
# [sub 41] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 41] movieframe_time_sec range=(0.000, 478.800)
# [sub 41] t_grid len=190992 source=uniform
# [sub 42] t_eye_raw range=(0.001, 813.863)
# [sub 42] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS42/sub-CS42_ses-P42CSR1_behavior+ecephys.nwb
# [sub 42] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 42] t_macro_movie range=(-10.000, 814.068)
# [sub 42] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 42] movieframe_time_sec range=(0.000, 478.800)
# [sub 42] t_grid len=206018 source=uniform
# [sub 43] t_eye_raw range=(0.000, 823.604)
# [sub 43] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS43/sub-CS43_ses-P43CSR1_behavior+ecephys.nwb
# [sub 43] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 43] t_macro_movie range=(-9.999, 823.868)
# [sub 43] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 43] movieframe_time_sec range=(0.000, 478.800)
# [sub 43] t_grid len=208468 source=uniform
# [sub 44] t_eye_raw range=(0.001, 887.669)
# [sub 44] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS44/sub-CS44_ses-P44CSR1_behavior+ecephys.nwb
# [sub 44] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 44] t_macro_movie range=(-9.999, 887.859)
# [sub 44] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 44] movieframe_time_sec range=(0.000, 478.800)
# [sub 44] t_grid len=224465 source=uniform
# [sub 47] t_eye_raw range=(0.000, 749.190)
# [sub 47] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS47/sub-CS47_ses-P47CSR1_behavior+ecephys.nwb
# [sub 47] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 47] t_macro_movie range=(-10.000, 749.446)
# [sub 47] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 47] movieframe_time_sec range=(0.000, 478.800)
# [sub 47] t_grid len=189862 source=uniform
# [sub 48] t_eye_raw range=(0.001, 820.715)
# [sub 48] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS48/sub-CS48_ses-P48CSR1_behavior+ecephys.nwb
# [sub 48] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 48] t_macro_movie range=(-9.999, 820.840)
# [sub 48] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 48] movieframe_time_sec range=(0.000, 478.800)
# [sub 48] t_grid len=207711 source=uniform
# [sub 49] t_eye_raw range=(0.001, 1025.465)
# [sub 49] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS49/sub-CS49_ses-P49CSR1_behavior+ecephys.nwb
# [sub 49] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 49] t_macro_movie range=(-9.999, 1025.540)
# [sub 49] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 49] movieframe_time_sec range=(0.000, 478.800)
# [sub 49] t_grid len=258886 source=uniform
# [sub 51] t_eye_raw range=(0.000, 852.196)
# [sub 51] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS51/sub-CS51_ses-P51CSR1_behavior+ecephys.nwb
# [sub 51] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 51] t_macro_movie range=(-9.999, 852.381)
# [sub 51] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 51] movieframe_time_sec range=(0.000, 478.800)
# [sub 51] t_grid len=215596 source=uniform
# [sub 53] t_eye_raw range=(0.001, 836.031)
# [sub 53] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS53/sub-CS53_ses-P53CSR1_behavior+ecephys.nwb
# [sub 53] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 53] t_macro_movie range=(-9.999, 836.266)
# [sub 53] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 53] movieframe_time_sec range=(0.000, 478.800)
# [sub 53] t_grid len=211567 source=uniform
# [sub 54] t_eye_raw range=(0.001, 918.711)
# [sub 54] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS54/sub-CS54_ses-P54CSR1_behavior+ecephys.nwb
# [sub 54] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 54] t_macro_movie range=(-9.999, 918.924)
# [sub 54] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 54] movieframe_time_sec range=(0.000, 478.800)
# [sub 54] t_grid len=232232 source=uniform
# [sub 55] t_eye_raw range=(0.001, 743.177)
# [sub 55] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS55/sub-CS55_ses-P55CSR1_behavior+ecephys.nwb
# [sub 55] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 55] t_macro_movie range=(-10.000, 743.296)
# [sub 55] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 55] movieframe_time_sec range=(0.000, 478.800)
# [sub 55] t_grid len=188325 source=uniform
# [sub 56] t_eye_raw range=(0.001, 966.405)
# [sub 56] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS56/sub-CS56_ses-P56CSR1_behavior+ecephys.nwb
# [sub 56] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 56] t_macro_movie range=(-10.000, 976.412)
# [sub 56] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 56] movieframe_time_sec range=(0.000, 478.800)
# [sub 56] t_grid len=246604 source=uniform
# [sub 57] t_eye_raw range=(0.000, 708.994)
# [sub 57] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS57/sub-CS57_ses-P57CSR1_behavior+ecephys.nwb
# [sub 57] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 57] t_macro_movie range=(-10.000, 708.993)
# [sub 57] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 57] movieframe_time_sec range=(0.000, 478.800)
# [sub 57] t_grid len=179749 source=uniform
# [sub 58] t_eye_raw range=(0.000, 695.162)
# [sub 58] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS58/sub-CS58_ses-P58CSR1_behavior+ecephys.nwb
# [sub 58] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 58] t_macro_movie range=(-10.000, 695.277)
# [sub 58] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 58] movieframe_time_sec range=(0.000, 478.800)
# [sub 58] t_grid len=176320 source=uniform
# [sub 60] t_eye_raw range=(0.001, 756.039)
# [sub 60] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS60/sub-CS60_ses-P60CSR1_behavior+ecephys.nwb
# [sub 60] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 60] t_macro_movie range=(-9.999, 756.139)
# [sub 60] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 60] movieframe_time_sec range=(0.000, 478.800)
# [sub 60] t_grid len=191535 source=uniform
# [sub 62] t_eye_raw range=(0.001, 808.145)
# [sub 62] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS62/sub-CS62_ses-P62CSR1_behavior+ecephys.nwb
# [sub 62] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 62] t_macro_movie range=(-10.000, 808.373)
# [sub 62] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 62] movieframe_time_sec range=(0.000, 478.800)
# [sub 62] t_grid len=204594 source=uniform
# dict_keys(['spikes', 'firing_rate', 'lfp_macro', 'lfp_micro', 'lfp_bandpower', 'eye_gaze', 'pupil', 'time_grid', 'movieframe_time', 'movieframe_time_sec', 'time_raw', 'bold', 'meta'])
# {'sub': 41, 'bids_sub': 'p41cs', 'nwb_sub': 'CS41', 'nwb_path': '/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS41/sub-CS41_ses-P41CSR1_behavior+ecephys.nwb', 'fs_macro_raw': np.float64(1000.0), 'fs_micro_raw': np.float64(1000.0), 'fs_eye_raw': np.float64(499.9999999976126), 'movie_fps_nominal': 25.0, 'grid_source': 'uniform', 'grid_dt': 0.004000000000019099, 'time_reference': 'movie_start_is_zero', 'lfp_baseline_seconds_pre_movie': 10.0, 'spikes_are_movie_referenced': True, 'lfp_is_movie_referenced_after_conversion': True, 'movieframe_time_is_frame_index': True, 'n_units': 7, 'fmri_error': None, 'max_nwb_samples': 2000000}
# (190992, 96) (190992, 2)
# band keys: ['theta', 'alpha', 'beta', 'gamma', 'high_gamma']
# (190992, 96) 190992

# %%
MODALITY_PCA_DICT = {
    "firing_rate": 5,
    "lfp_micro": 32,
    "lfp_macro": 32,
    "eye_gaze": 5,
    "pupil": 0,
}

data_pca = feature.apply_subjectwise_pca_to_modalities(
    data,
    modality_pca_dict=MODALITY_PCA_DICT,
    copy_data=True,
    fillna_value=0.0,
    store_pca_model=False,
    verbose=True,
)
# Out:
# [pca] sub=41, modality=firing_rate: (190992, 7) -> (190992, 5), explained_var_sum=0.9013
# [pca] sub=41, modality=lfp_micro: (190992, 80) -> (190992, 32), explained_var_sum=0.9967
# [pca] sub=41, modality=lfp_macro: (190992, 96) -> (190992, 32), explained_var_sum=0.9386
# [keep] sub=41, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=41, modality=pupil: target_dim=0, keep original
# [pca] sub=42, modality=firing_rate: (206018, 50) -> (206018, 5), explained_var_sum=0.3156
# [pca] sub=42, modality=lfp_micro: (206018, 64) -> (206018, 32), explained_var_sum=0.9853
# [pca] sub=42, modality=lfp_macro: (206018, 96) -> (206018, 32), explained_var_sum=0.9519
# [keep] sub=42, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=42, modality=pupil: target_dim=0, keep original
# [pca] sub=43, modality=firing_rate: (208468, 32) -> (208468, 5), explained_var_sum=0.5569
# [pca] sub=43, modality=lfp_micro: (208468, 80) -> (208468, 32), explained_var_sum=0.9765
# [pca] sub=43, modality=lfp_macro: (208468, 96) -> (208468, 32), explained_var_sum=0.9247
# [keep] sub=43, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=43, modality=pupil: target_dim=0, keep original
# [pca] sub=44, modality=firing_rate: (224465, 49) -> (224465, 5), explained_var_sum=0.3201
# [pca] sub=44, modality=lfp_micro: (224465, 64) -> (224465, 32), explained_var_sum=0.9941
# [pca] sub=44, modality=lfp_macro: (224465, 96) -> (224465, 32), explained_var_sum=0.9256
# [keep] sub=44, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=44, modality=pupil: target_dim=0, keep original
# [pca] sub=47, modality=firing_rate: (189862, 75) -> (189862, 5), explained_var_sum=0.4106
# [pca] sub=47, modality=lfp_micro: (189862, 80) -> (189862, 32), explained_var_sum=0.9854
# [pca] sub=47, modality=lfp_macro: (189862, 96) -> (189862, 32), explained_var_sum=0.9859
# [keep] sub=47, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=47, modality=pupil: target_dim=0, keep original
# [pca] sub=48, modality=firing_rate: (207711, 143) -> (207711, 5), explained_var_sum=0.2162
# [pca] sub=48, modality=lfp_micro: (207711, 80) -> (207711, 32), explained_var_sum=0.9900
# [pca] sub=48, modality=lfp_macro: (207711, 96) -> (207711, 32), explained_var_sum=0.9437
# [keep] sub=48, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=48, modality=pupil: target_dim=0, keep original
# [pca] sub=49, modality=firing_rate: (258886, 12) -> (258886, 5), explained_var_sum=0.8112
# [pca] sub=49, modality=lfp_micro: (258886, 80) -> (258886, 32), explained_var_sum=0.9783
# [pca] sub=49, modality=lfp_macro: (258886, 96) -> (258886, 32), explained_var_sum=0.9458
# [keep] sub=49, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=49, modality=pupil: target_dim=0, keep original
# [pca] sub=51, modality=firing_rate: (215596, 30) -> (215596, 5), explained_var_sum=0.5371
# [pca] sub=51, modality=lfp_micro: (215596, 80) -> (215596, 32), explained_var_sum=0.9703
# [pca] sub=51, modality=lfp_macro: (215596, 128) -> (215596, 32), explained_var_sum=0.8794
# [keep] sub=51, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=51, modality=pupil: target_dim=0, keep original
# [pca] sub=53, modality=firing_rate: (211567, 34) -> (211567, 5), explained_var_sum=0.4196
# [pca] sub=53, modality=lfp_micro: (211567, 80) -> (211567, 32), explained_var_sum=0.9569
# [pca] sub=53, modality=lfp_macro: (211567, 96) -> (211567, 32), explained_var_sum=0.9478
# [keep] sub=53, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=53, modality=pupil: target_dim=0, keep original
# [pca] sub=54, modality=firing_rate: (232232, 123) -> (232232, 5), explained_var_sum=0.1916
# [pca] sub=54, modality=lfp_micro: (232232, 80) -> (232232, 32), explained_var_sum=0.9881
# [pca] sub=54, modality=lfp_macro: (232232, 96) -> (232232, 32), explained_var_sum=0.9275
# [keep] sub=54, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=54, modality=pupil: target_dim=0, keep original
# [pca] sub=55, modality=firing_rate: (188325, 57) -> (188325, 5), explained_var_sum=0.3221
# [pca] sub=55, modality=lfp_micro: (188325, 80) -> (188325, 32), explained_var_sum=0.9749
# [pca] sub=55, modality=lfp_macro: (188325, 96) -> (188325, 32), explained_var_sum=0.9551
# [keep] sub=55, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=55, modality=pupil: target_dim=0, keep original
# [pca] sub=56, modality=firing_rate: (246604, 30) -> (246604, 5), explained_var_sum=0.4096
# [pca] sub=56, modality=lfp_micro: (246604, 80) -> (246604, 32), explained_var_sum=0.9865
# [pca] sub=56, modality=lfp_macro: (246604, 106) -> (246604, 32), explained_var_sum=0.9409
# [keep] sub=56, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=56, modality=pupil: target_dim=0, keep original
# [pca] sub=57, modality=firing_rate: (179749, 33) -> (179749, 5), explained_var_sum=0.4253
# [pca] sub=57, modality=lfp_micro: (179749, 80) -> (179749, 32), explained_var_sum=0.9638
# [pca] sub=57, modality=lfp_macro: (179749, 102) -> (179749, 32), explained_var_sum=0.9780
# [keep] sub=57, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=57, modality=pupil: target_dim=0, keep original
# [pca] sub=58, modality=firing_rate: (176320, 89) -> (176320, 5), explained_var_sum=0.2957
# [pca] sub=58, modality=lfp_micro: (176320, 80) -> (176320, 32), explained_var_sum=0.9455
# [pca] sub=58, modality=lfp_macro: (176320, 86) -> (176320, 32), explained_var_sum=0.9815
# [keep] sub=58, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=58, modality=pupil: target_dim=0, keep original
# [pca] sub=60, modality=firing_rate: (191535, 27) -> (191535, 5), explained_var_sum=0.5540
# [pca] sub=60, modality=lfp_micro: (191535, 80) -> (191535, 32), explained_var_sum=0.9859
# [pca] sub=60, modality=lfp_macro: (191535, 92) -> (191535, 32), explained_var_sum=0.9497
# [keep] sub=60, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=60, modality=pupil: target_dim=0, keep original
# [pca] sub=62, modality=firing_rate: (204594, 44) -> (204594, 5), explained_var_sum=0.4696
# [pca] sub=62, modality=lfp_micro: (204594, 56) -> (204594, 32), explained_var_sum=0.9899
# [pca] sub=62, modality=lfp_macro: (204594, 40) -> (204594, 32), explained_var_sum=0.9970
# [keep] sub=62, modality=eye_gaze: target_dim >= D (5 >= 2)
# [keep] sub=62, modality=pupil: target_dim=0, keep original

# %%
eye_data = data_pca[41]["eye_gaze"]
print("movie_time shape:", data[41]["movieframe_time"].shape)
print("eye_gaze shape:", eye_data.shape)
print(eye_data[:5])
# Out:
# movie_time shape: (11971,)
# eye_gaze shape: (190992, 2)
# [[630.07562256 548.12335205]
#  [630.07562256 548.12335205]
#  [630.07562256 548.12335205]
#  [630.07562256 548.12335205]
#  [630.07562256 548.12335205]]

# %% [markdown]
# # 4. Face Encoding Model
# ## 4.1 Feature Engineering

# %%
norm_modality_dict = {
    "firing_rate": [True, "max"],
    "lfp_macro": [False, "zscore"],
    "lfp_micro": [False, "zscore"],
    "eye_gaze": [True, "min_max"],
    "pupil": [True, "max"],
}

all_window_data = feature.build_all_subject_window_datasets(
    out=data_pca,
    df_face_note=df_face_note,
    window_size_sec=0.5,          # 500 ms
    stride_sec=0.25,               # 100 ms stride
    start_time=0.0,
    end_time=478.800,
    remove_baseline_windows=True,
    do_baseline_norm=True,
    norm_modality_dict=norm_modality_dict,
    baseline_mode="zscore",
    baseline_start=-10.0,
    baseline_end=0.0,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    use_only_valid_face_frames=True,
    valid_face_mode="front_or_face",
    require_all_modalities_nonempty=False,
    verbose=True,
)

all_window_data_filtered = {}

# filter valid window, face ratio, min_frame
for sub, sub_data in all_window_data.items():
    all_window_data_filtered[sub] = feature.filter_window_dataset(
        sub_data,
        valid_window_only=True,
        min_valid_face_ratio=0.25,
        min_face_frames=5,
        min_non_neutral=None,
        allowed_hard_labels=None,
        require_modalities_nonempty=["firing_rate"],
        verbose=True,
    )

concat_data = feature.concat_subject_window_data(
    all_window_data_filtered,
    subjects=None,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    add_subject_column=True,
    reset_index=True,
    verbose=True,
)
# Out:
# [build] subject 41
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 42
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 43
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 44
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 47
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 48
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 49
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 51
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 53
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 54
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 55
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 56
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 57
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 58
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 60
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [build] subject 62
# normalized modality 'lfp_macro' with baseline mode 'zscore' using 2500 baseline samples.
# normalized modality 'lfp_micro' with baseline mode 'zscore' using 2500 baseline samples.
#   -> n_windows = 1914, valid_windows = 1914
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [filter_window_dataset] kept 1520 / 1914 windows
# [concat] sub=41, n_windows=1520
# [concat] sub=42, n_windows=1520
# [concat] sub=43, n_windows=1520
# [concat] sub=44, n_windows=1520
# [concat] sub=47, n_windows=1520
# [concat] sub=48, n_windows=1520
# [concat] sub=49, n_windows=1520
# [concat] sub=51, n_windows=1520
# [concat] sub=53, n_windows=1520
# [concat] sub=54, n_windows=1520
# [concat] sub=55, n_windows=1520
# [concat] sub=56, n_windows=1520
# [concat] sub=57, n_windows=1520
# [concat] sub=58, n_windows=1520
# [concat] sub=60, n_windows=1520
# [concat] sub=62, n_windows=1520
# [concat_subject_window_data] total windows = 24320

# %%
# numeric_label_configs = {
#     "emo_neutral": {
#         "y_col": "emo_neutral",
#         "mode": "binary",
#         "threshold": 0.5,
#     },
#     "jacky_ratio": {
#         "y_col": "jacky_ratio",
#         "mode": "binary",
#         "threshold": 0.5,
#     },
#     "front_face_ratio": {
#         "y_col": "front_face_ratio",
#         "mode": "binary",
#         "threshold": 0.5,
#     },
# }

numeric_label_configs = {
    "emo_neutral": {
        "y_col": "emo_neutral",
        "mode": "continuous",
    },
    "jacky_ratio": {
        "y_col": "jacky_ratio",
        "mode": "continuous",
    },
    "front_face_ratio": {
        "y_col": "front_face_ratio",
        "mode": "continuous",
    },
}

out = dataset_builder.build_train_test_datasets_from_concat_data(
    concat_data=concat_data,
    modality_keys=["lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    # y_labels=["gaze", "pupil"],
    y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", ],
    # y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", "gaze", "pupil"],
    sub_col="sub",
    modality_reduce_modes={
        "lfp_macro": "none",
        "lfp_micro": "none",
        "eye_gaze": "none",
        "pupil": "none",
    },
    sequence_label_configs={
        "gaze": {
            "seq_key": "eye_gaze",
            "reduce_mode": "mean",
        },
        "pupil": {
            "seq_key": "pupil",
            "reduce_mode": "last",
        },
    },
    numeric_label_configs=numeric_label_configs,
    test_ratio=0.2,
    batch_size=128,
    random_seed=42,
)

# %%
print(out.keys())
print(len(out['samples']))
# Out:
# dict_keys(['dataset', 'train_dataset', 'test_dataset', 'train_loader', 'test_loader', 'samples', 'label_meta', 'modality_keys', 'y_labels'])
# 24320

# %% [markdown]
# # Train with eye decoder

# %%
out = dataset_builder.build_train_test_datasets_from_concat_data(
    concat_data=concat_data,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro"],
    y_labels=["gaze", "pupil"],
    # y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", ],
    # y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", "gaze", "pupil"],
    sub_col="sub",
    modality_reduce_modes={
        "lfp_macro": "none",
        "lfp_micro": "none",
        "eye_gaze": "none",
        "pupil": "none",
    },
    sequence_label_configs={
        "gaze": {
            "seq_key": "eye_gaze",
            "reduce_mode": "mean",
        },
        "pupil": {
            "seq_key": "pupil",
            "reduce_mode": "mean",
        },
    },
    numeric_label_configs=numeric_label_configs,
    test_ratio=0.2,
    batch_size=128,
    random_seed=42,
)

train_loader = out["train_loader"]
test_loader = out["test_loader"]

model = full_model.MultiModalFusionModel(
    modalities=["firing_rate", "lfp_macro", "lfp_micro"],
    n_temporal_layers=2,
    b_mod_early_fusion=False,
    d_encoder_dim=32,
    d_encoder_hidden=128,
    encoder_time_dilation=1,
    encoder_time_kernel=7,
    b_use_maxpooling_layer=True,
    sequential_model_hidden=64,
    sequential_model_type="transformer",
    sequential_model_layers=2,
    sequential_pooling="attn",
    dropout=0.1,
    outhead="eye_decode",
    label_dim=3,
)

cfg = Trainer.TrainConfig(
    epochs=300,
    batch_size=128,
    lr=3e-4,
    save_path="best_model.pt",
    y_order=["gaze", "pupil"],
    early_stop_patience=10,
)

history, best_path = Trainer.run_training_with_loaders(
    model,
    train_loader,
    test_loader,
    cfg,
    loss="smooth_l1",
    device="cpu",
)
print("best saved to:", best_path)

eval_metrics, out = metrics.evaluate_model(
    model,
    test_loader,
    y_order=["gaze", "pupil"],
    device="cpu",
)
# Out:
# Epoch 001/300 | lr 3.00e-04 | train loss 0.030328 | val loss 0.027106 | best 0.027106 (ep 001) | es 0/10 | improved
# Epoch 002/300 | lr 3.00e-04 | train loss 0.025952 | val loss 0.047254 | best 0.027106 (ep 001) | es 1/10
# Epoch 003/300 | lr 3.00e-04 | train loss 0.024591 | val loss 0.105417 | best 0.027106 (ep 001) | es 2/10
# Epoch 004/300 | lr 3.00e-04 | train loss 0.022552 | val loss 0.114470 | best 0.027106 (ep 001) | es 3/10
# Epoch 005/300 | lr 3.00e-04 | train loss 0.021442 | val loss 0.101217 | best 0.027106 (ep 001) | es 4/10 | lr-> 1.50e-04
# Epoch 006/300 | lr 1.50e-04 | train loss 0.020116 | val loss 0.103724 | best 0.027106 (ep 001) | es 5/10
# Epoch 007/300 | lr 1.50e-04 | train loss 0.019680 | val loss 0.104495 | best 0.027106 (ep 001) | es 6/10
# Epoch 008/300 | lr 1.50e-04 | train loss 0.019363 | val loss 0.103490 | best 0.027106 (ep 001) | es 7/10
# Epoch 009/300 | lr 1.50e-04 | train loss 0.019166 | val loss 0.094811 | best 0.027106 (ep 001) | es 8/10 | lr-> 7.50e-05
# Epoch 010/300 | lr 7.50e-05 | train loss 0.018556 | val loss 0.096702 | best 0.027106 (ep 001) | es 9/10
# Epoch 011/300 | lr 7.50e-05 | train loss 0.018500 | val loss 0.089859 | best 0.027106 (ep 001) | es 10/10
# Early stopping triggered at epoch 11. Best epoch = 1.
# Loaded best model from epoch 1 with val loss 0.027105778798853095
# best saved to: best_model.pt
# === Test metrics ===
#
# gaze
#   gaze_0
#     mae: 0.080618
#     mse: 0.010583
#     rmse: 0.102874
#     r2: 0.052714
#   gaze_1
#     mae: 0.077312
#     mse: 0.008868
#     rmse: 0.094170
#     r2: 0.026212
#   gaze_all
#     mae: 0.078965
#     mse: 0.009725
#     rmse: 0.098618
#
# pupil
#   mae: 0.219992
#   mse: 0.061875
#   rmse: 0.248747
#   r2: -0.078220

# %%
metrics.evaluate_eye_model(model, test_loader, device="cpu")
# Out:
# === Test metrics ===
#
# gaze_x
#   mae: 0.081389
#   mse: 0.010418
#   rmse: 0.102071
#   r2: 0.067444
#
# gaze_y
#   mae: 0.077383
#   mse: 0.008984
#   rmse: 0.094784
#   r2: 0.013468
#
# pupil
#   mae: 0.204108
#   mse: 0.057522
#   rmse: 0.239837
#   r2: 0.073485
#
# gaze_all
#   mae: 0.079386
#   mse: 0.009701
#   rmse: 0.098495
# ({'gaze_x': {'mae': 0.08138871192932129,
#    'mse': 0.01041843555867672,
#    'rmse': 0.10207074135541916,
#    'r2': 0.0674436092376709},
#   'gaze_y': {'mae': 0.07738258689641953,
#    'mse': 0.008984007872641087,
#    'rmse': 0.09478400647640228,
#    'r2': 0.013468146324157715},
#   'pupil': {'mae': 0.20410779118537903,
#    'mse': 0.057521894574165344,
#    'rmse': 0.23983722925186157,
#    'r2': 0.07348477840423584},
#   'gaze_all': {'mae': 0.07938564568758011,
#    'mse': 0.009701221249997616,
#    'rmse': 0.09849477559328079}},
#  {'y_true': array([[0.44828993, 0.41286942, 0.6261403 ],
#          [0.5127634 , 0.27109307, 0.6001797 ],
#          [0.33135888, 0.55783975, 0.4653449 ],
#          ...,
#          [0.4469127 , 0.38713348, 0.09915003],
#          [0.38329282, 0.29547918, 0.08475634],
#          [0.5105829 , 0.5489882 , 0.10265316]],
#         shape=(4864, 3), dtype=float32),
#   'y_pred': array([[0.4953205 , 0.37248504, 0.3510505 ],
#          [0.44342667, 0.35053295, 0.4631438 ],
#          [0.4699515 , 0.38073486, 0.4039255 ],
#          ...,
#          [0.49305546, 0.38503978, 0.31017956],
#          [0.4911431 , 0.37900752, 0.32046655],
#          [0.5146945 , 0.4239546 , 0.33580175]],
#         shape=(4864, 3), dtype=float32),
#   'sub': [np.int64(44),
#    np.int64(49),
#    np.int64(47),
#    np.int64(41),
#    np.int64(53),
#    np.int64(41),
#    np.int64(43),
#    np.int64(57),
#    np.int64(55),
#    np.int64(53),
#    np.int64(54),
#    np.int64(57),
#    np.int64(44),
#    np.int64(43),
#    np.int64(55),
#    np.int64(49),
#    np.int64(62),
#    np.int64(60),
#    np.int64(60),
#    np.int64(56),
#    np.int64(42),
#    np.int64(44),
#    np.int64(51),
#    np.int64(58),
#    np.int64(60),
#    np.int64(56),
#    np.int64(44),
#    np.int64(60),
#    np.int64(55),
#    np.int64(54),
#    np.int64(56),
#    np.int64(54),
#    np.int64(57),
#    np.int64(49),
#    np.int64(42),
#    np.int64(55),
#    np.int64(48),
#    np.int64(44),
#    np.int64(62),
#    np.int64(48),
#    np.int64(58),
#    np.int64(57),
#    np.int64(60),
#    np.int64(48),
#    np.int64(43),
#    np.int64(56),
#    np.int64(55),
#    np.int64(62),
#    np.int64(44),
#    np.int64(53),
#    np.int64(49),
#    np.int64(53),
#    np.int64(47),
#    np.int64(42),
#    np.int64(44),
#    np.int64(53),
#    np.int64(58),
#    np.int64(53),
#    np.int64(55),
#    np.int64(49),
#    np.int64(47),
#    np.int64(53),
#    np.int64(41),
#    np.int64(54),
#    np.int64(48),
#    np.int64(53),
#    np.int64(41),
#    np.int64(57),
#    np.int64(58),
#    np.int64(48),
#    np.int64(55),
#    np.int64(53),
#    np.int64(43),
#    np.int64(47),
#    np.int64(62),
#    np.int64(47),
#    np.int64(43),
#    np.int64(62),
#    np.int64(47),
#    np.int64(58),
#    np.int64(60),
#    np.int64(51),
#    np.int64(57),
#    np.int64(42),
#    np.int64(56),
#    np.int64(43),
#    np.int64(48),
#    np.int64(55),
#    np.int64(53),
#    np.int64(51),
#    np.int64(41),
#    np.int64(44),
#    np.int64(55),
#    np.int64(56),
#    np.int64(49),
#    np.int64(53),
#    np.int64(60),
#    np.int64(62),
#    np.int64(62),
#    np.int64(53),
#    np.int64(53),
#    np.int64(49),
#    np.int64(48),
#    np.int64(47),
#    np.int64(54),
#    np.int64(56),
#    np.int64(58),
#    np.int64(56),
#    np.int64(54),
#    np.int64(42),
#    np.int64(44),
#    np.int64(51),
#    np.int64(43),
#    np.int64(55),
#    np.int64(41),
#    np.int64(47),
#    np.int64(41),
#    np.int64(58),
#    np.int64(42),
#    np.int64(44),
#    np.int64(48),
#    np.int64(56),
#    np.int64(51),
#    np.int64(44),
#    np.int64(54),
#    np.int64(62),
#    np.int64(57),
#    np.int64(62),
#    np.int64(62),
#    np.int64(51),
#    np.int64(58),
#    np.int64(44),
#    np.int64(57),
#    np.int64(44),
#    np.int64(48),
#    np.int64(42),
#    np.int64(41),
#    np.int64(47),
#    np.int64(54),
#    np.int64(60),
#    np.int64(60),
#    np.int64(48),
#    np.int64(55),
#    np.int64(48),
#    np.int64(62),
#    np.int64(54),
#    np.int64(48),
#    np.int64(56),
#    np.int64(44),
#    np.int64(41),
#    np.int64(56),
#    np.int64(49),
#    np.int64(58),
#    np.int64(60),
#    np.int64(55),
#    np.int64(62),
#    np.int64(56),
#    np.int64(60),
#    np.int64(51),
#    np.int64(56),
#    np.int64(55),
#    np.int64(49),
#    np.int64(42),
#    np.int64(44),
#    np.int64(43),
#    np.int64(54),
#    np.int64(47),
#    np.int64(41),
#    np.int64(43),
#    np.int64(49),
#    np.int64(56),
#    np.int64(41),
#    np.int64(49),
#    np.int64(44),
#    np.int64(58),
#    np.int64(58),
#    np.int64(51),
#    np.int64(56),
#    np.int64(43),
#    np.int64(57),
#    np.int64(56),
#    np.int64(42),
#    np.int64(42),
#    np.int64(56),
#    np.int64(48),
#    np.int64(57),
#    np.int64(53),
#    np.int64(51),
#    np.int64(55),
#    np.int64(57),
#    np.int64(54),
#    np.int64(49),
#    np.int64(58),
#    np.int64(60),
#    np.int64(47),
#    np.int64(41),
#    np.int64(49),
#    np.int64(48),
#    np.int64(49),
#    np.int64(47),
#    np.int64(49),
#    np.int64(57),
#    np.int64(51),
#    np.int64(51),
#    np.int64(57),
#    np.int64(56),
#    np.int64(41),
#    np.int64(60),
#    np.int64(47),
#    np.int64(48),
#    np.int64(55),
#    np.int64(49),
#    np.int64(49),
#    np.int64(41),
#    np.int64(49),
#    np.int64(55),
#    np.int64(62),
#    np.int64(54),
#    np.int64(44),
#    np.int64(49),
#    np.int64(51),
#    np.int64(55),
#    np.int64(57),
#    np.int64(56),
#    np.int64(51),
#    np.int64(57),
#    np.int64(60),
#    np.int64(53),
#    np.int64(60),
#    np.int64(58),
#    np.int64(54),
#    np.int64(62),
#    np.int64(51),
#    np.int64(55),
#    np.int64(51),
#    np.int64(57),
#    np.int64(53),
#    np.int64(51),
#    np.int64(57),
#    np.int64(53),
#    np.int64(54),
#    np.int64(53),
#    np.int64(41),
#    np.int64(42),
#    np.int64(57),
#    np.int64(53),
#    np.int64(44),
#    np.int64(49),
#    np.int64(47),
#    np.int64(51),
#    np.int64(43),
#    np.int64(44),
#    np.int64(44),
#    np.int64(51),
#    np.int64(47),
#    np.int64(47),
#    np.int64(49),
#    np.int64(47),
#    np.int64(42),
#    np.int64(47),
#    np.int64(58),
#    np.int64(47),
#    np.int64(60),
#    np.int64(54),
#    np.int64(62),
#    np.int64(56),
#    np.int64(55),
#    np.int64(60),
#    np.int64(49),
#    np.int64(60),
#    np.int64(41),
#    np.int64(54),
#    np.int64(53),
#    np.int64(43),
#    np.int64(44),
#    np.int64(42),
#    np.int64(48),
#    np.int64(53),
#    np.int64(47),
#    np.int64(55),
#    np.int64(62),
#    np.int64(51),
#    np.int64(60),
#    np.int64(43),
#    np.int64(53),
#    np.int64(47),
#    np.int64(54),
#    np.int64(44),
#    np.int64(47),
#    np.int64(51),
#    np.int64(49),
#    np.int64(48),
#    np.int64(62),
#    np.int64(62),
#    np.int64(53),
#    np.int64(48),
#    np.int64(43),
#    np.int64(56),
#    np.int64(58),
#    np.int64(44),
#    np.int64(51),
#    np.int64(47),
#    np.int64(55),
#    np.int64(53),
#    np.int64(55),
#    np.int64(53),
#    np.int64(57),
#    np.int64(47),
#    np.int64(57),
#    np.int64(42),
#    np.int64(47),
#    np.int64(53),
#    np.int64(41),
#    np.int64(55),
#    np.int64(47),
#    np.int64(49),
#    np.int64(49),
#    np.int64(44),
#    np.int64(62),
#    np.int64(42),
#    np.int64(57),
#    np.int64(43),
#    np.int64(42),
#    np.int64(58),
#    np.int64(56),
#    np.int64(58),
#    np.int64(53),
#    np.int64(60),
#    np.int64(43),
#    np.int64(51),
#    np.int64(56),
#    np.int64(47),
#    np.int64(51),
#    np.int64(41),
#    np.int64(47),
#    np.int64(43),
#    np.int64(58),
#    np.int64(41),
#    np.int64(53),
#    np.int64(51),
#    np.int64(51),
#    np.int64(53),
#    np.int64(55),
#    np.int64(57),
#    np.int64(47),
#    np.int64(41),
#    np.int64(42),
#    np.int64(55),
#    np.int64(54),
#    np.int64(60),
#    np.int64(42),
#    np.int64(48),
#    np.int64(57),
#    np.int64(44),
#    np.int64(48),
#    np.int64(54),
#    np.int64(55),
#    np.int64(54),
#    np.int64(49),
#    np.int64(53),
#    np.int64(57),
#    np.int64(62),
#    np.int64(54),
#    np.int64(51),
#    np.int64(54),
#    np.int64(49),
#    np.int64(42),
#    np.int64(53),
#    np.int64(42),
#    np.int64(57),
#    np.int64(57),
#    np.int64(42),
#    np.int64(56),
#    np.int64(49),
#    np.int64(42),
#    np.int64(41),
#    np.int64(44),
#    np.int64(44),
#    np.int64(42),
#    np.int64(51),
#    np.int64(60),
#    np.int64(44),
#    np.int64(51),
#    np.int64(54),
#    np.int64(43),
#    np.int64(58),
#    np.int64(41),
#    np.int64(60),
#    np.int64(47),
#    np.int64(56),
#    np.int64(43),
#    np.int64(41),
#    np.int64(41),
#    np.int64(53),
#    np.int64(41),
#    np.int64(48),
#    np.int64(60),
#    np.int64(44),
#    np.int64(60),
#    np.int64(53),
#    np.int64(47),
#    np.int64(48),
#    np.int64(47),
#    np.int64(55),
#    np.int64(49),
#    np.int64(41),
#    np.int64(56),
#    np.int64(53),
#    np.int64(49),
#    np.int64(44),
#    np.int64(57),
#    np.int64(49),
#    np.int64(60),
#    np.int64(44),
#    np.int64(49),
#    np.int64(58),
#    np.int64(55),
#    np.int64(58),
#    np.int64(47),
#    np.int64(51),
#    np.int64(54),
#    np.int64(55),
#    np.int64(53),
#    np.int64(58),
#    np.int64(42),
#    np.int64(42),
#    np.int64(51),
#    np.int64(58),
#    np.int64(48),
#    np.int64(60),
#    np.int64(49),
#    np.int64(49),
#    np.int64(48),
#    np.int64(47),
#    np.int64(44),
#    np.int64(62),
#    np.int64(55),
#    np.int64(47),
#    np.int64(62),
#    np.int64(41),
#    np.int64(41),
#    np.int64(60),
#    np.int64(47),
#    np.int64(47),
#    np.int64(62),
#    np.int64(41),
#    np.int64(42),
#    np.int64(56),
#    np.int64(58),
#    np.int64(48),
#    np.int64(48),
#    np.int64(42),
#    np.int64(55),
#    np.int64(55),
#    np.int64(48),
#    np.int64(56),
#    np.int64(55),
#    np.int64(44),
#    np.int64(44),
#    np.int64(55),
#    np.int64(57),
#    np.int64(41),
#    np.int64(56),
#    np.int64(43),
#    np.int64(53),
#    np.int64(62),
#    np.int64(43),
#    np.int64(51),
#    np.int64(56),
#    np.int64(60),
#    np.int64(44),
#    np.int64(54),
#    np.int64(44),
#    np.int64(51),
#    np.int64(60),
#    np.int64(43),
#    np.int64(53),
#    np.int64(55),
#    np.int64(44),
#    np.int64(55),
#    np.int64(41),
#    np.int64(57),
#    np.int64(57),
#    np.int64(62),
#    np.int64(56),
#    np.int64(48),
#    np.int64(53),
#    np.int64(54),
#    np.int64(53),
#    np.int64(60),
#    np.int64(49),
#    np.int64(60),
#    np.int64(60),
#    np.int64(49),
#    np.int64(41),
#    np.int64(54),
#    np.int64(54),
#    np.int64(56),
#    np.int64(62),
#    np.int64(57),
#    np.int64(57),
#    np.int64(56),
#    np.int64(44),
#    np.int64(57),
#    np.int64(54),
#    np.int64(55),
#    np.int64(43),
#    np.int64(47),
#    np.int64(42),
#    np.int64(60),
#    np.int64(53),
#    np.int64(57),
#    np.int64(55),
#    np.int64(43),
#    np.int64(60),
#    np.int64(54),
#    np.int64(56),
#    np.int64(43),
#    np.int64(57),
#    np.int64(42),
#    np.int64(62),
#    np.int64(44),
#    np.int64(41),
#    np.int64(42),
#    np.int64(62),
#    np.int64(51),
#    np.int64(60),
#    np.int64(44),
#    np.int64(49),
#    np.int64(47),
#    np.int64(44),
#    np.int64(48),
#    np.int64(53),
#    np.int64(42),
#    np.int64(54),
#    np.int64(54),
#    np.int64(42),
#    np.int64(51),
#    np.int64(55),
#    np.int64(42),
#    np.int64(47),
#    np.int64(48),
#    np.int64(47),
#    np.int64(51),
#    np.int64(56),
#    np.int64(57),
#    np.int64(57),
#    np.int64(55),
#    np.int64(58),
#    np.int64(56),
#    np.int64(57),
#    np.int64(56),
#    np.int64(48),
#    np.int64(51),
#    np.int64(53),
#    np.int64(57),
#    np.int64(48),
#    np.int64(56),
#    np.int64(41),
#    np.int64(41),
#    np.int64(62),
#    np.int64(51),
#    np.int64(55),
#    np.int64(43),
#    np.int64(47),
#    np.int64(47),
#    np.int64(49),
#    np.int64(58),
#    np.int64(42),
#    np.int64(42),
#    np.int64(42),
#    np.int64(56),
#    np.int64(54),
#    np.int64(43),
#    np.int64(43),
#    np.int64(41),
#    np.int64(44),
#    np.int64(44),
#    np.int64(51),
#    np.int64(41),
#    np.int64(43),
#    np.int64(42),
#    np.int64(49),
#    np.int64(44),
#    np.int64(42),
#    np.int64(54),
#    np.int64(58),
#    np.int64(56),
#    np.int64(44),
#    np.int64(49),
#    np.int64(60),
#    np.int64(51),
#    np.int64(56),
#    np.int64(43),
#    np.int64(54),
#    np.int64(54),
#    np.int64(60),
#    np.int64(43),
#    np.int64(47),
#    np.int64(58),
#    np.int64(51),
#    np.int64(44),
#    np.int64(42),
#    np.int64(57),
#    np.int64(62),
#    np.int64(43),
#    np.int64(43),
#    np.int64(44),
#    np.int64(62),
#    np.int64(47),
#    np.int64(47),
#    np.int64(43),
#    np.int64(53),
#    np.int64(54),
#    np.int64(56),
#    np.int64(57),
#    np.int64(58),
#    np.int64(55),
#    np.int64(62),
#    np.int64(47),
#    np.int64(43),
#    np.int64(49),
#    np.int64(58),
#    np.int64(41),
#    np.int64(54),
#    np.int64(60),
#    np.int64(49),
#    np.int64(54),
#    np.int64(54),
#    np.int64(44),
#    np.int64(55),
#    np.int64(44),
#    np.int64(44),
#    np.int64(56),
#    np.int64(42),
#    np.int64(44),
#    np.int64(43),
#    np.int64(42),
#    np.int64(53),
#    np.int64(60),
#    np.int64(44),
#    np.int64(49),
#    np.int64(57),
#    np.int64(62),
#    np.int64(58),
#    np.int64(48),
#    np.int64(48),
#    np.int64(58),
#    np.int64(58),
#    np.int64(57),
#    np.int64(49),
#    np.int64(60),
#    np.int64(49),
#    np.int64(47),
#    np.int64(51),
#    np.int64(54),
#    np.int64(57),
#    np.int64(55),
#    np.int64(49),
#    np.int64(55),
#    np.int64(49),
#    np.int64(43),
#    np.int64(54),
#    np.int64(58),
#    np.int64(51),
#    np.int64(44),
#    np.int64(43),
#    np.int64(42),
#    np.int64(57),
#    np.int64(41),
#    np.int64(43),
#    np.int64(62),
#    np.int64(55),
#    np.int64(43),
#    np.int64(60),
#    np.int64(49),
#    np.int64(54),
#    np.int64(62),
#    np.int64(43),
#    np.int64(62),
#    np.int64(44),
#    np.int64(53),
#    np.int64(60),
#    np.int64(48),
#    np.int64(53),
#    np.int64(54),
#    np.int64(54),
#    np.int64(41),
#    np.int64(54),
#    np.int64(49),
#    np.int64(49),
#    np.int64(41),
#    np.int64(49),
#    np.int64(48),
#    np.int64(58),
#    np.int64(49),
#    np.int64(56),
#    np.int64(54),
#    np.int64(48),
#    np.int64(55),
#    np.int64(42),
#    np.int64(57),
#    np.int64(48),
#    np.int64(53),
#    np.int64(42),
#    np.int64(56),
#    np.int64(48),
#    np.int64(42),
#    np.int64(47),
#    np.int64(48),
#    np.int64(51),
#    np.int64(62),
#    np.int64(57),
#    np.int64(44),
#    np.int64(53),
#    np.int64(51),
#    np.int64(49),
#    np.int64(62),
#    np.int64(48),
#    np.int64(60),
#    np.int64(51),
#    np.int64(54),
#    np.int64(55),
#    np.int64(51),
#    np.int64(42),
#    np.int64(57),
#    np.int64(56),
#    np.int64(43),
#    np.int64(43),
#    np.int64(55),
#    np.int64(48),
#    np.int64(41),
#    np.int64(44),
#    np.int64(60),
#    np.int64(43),
#    np.int64(53),
#    np.int64(44),
#    np.int64(62),
#    np.int64(42),
#    np.int64(58),
#    np.int64(58),
#    np.int64(55),
#    np.int64(55),
#    np.int64(53),
#    np.int64(62),
#    np.int64(41),
#    np.int64(57),
#    np.int64(56),
#    np.int64(49),
#    np.int64(48),
#    np.int64(42),
#    np.int64(56),
#    np.int64(48),
#    np.int64(49),
#    np.int64(55),
#    np.int64(60),
#    np.int64(41),
#    np.int64(55),
#    np.int64(53),
#    np.int64(57),
#    np.int64(54),
#    np.int64(41),
#    np.int64(49),
#    np.int64(48),
#    np.int64(41),
#    np.int64(51),
#    np.int64(56),
#    np.int64(56),
#    np.int64(62),
#    np.int64(41),
#    np.int64(41),
#    np.int64(53),
#    np.int64(60),
#    np.int64(48),
#    np.int64(54),
#    np.int64(53),
#    np.int64(49),
#    np.int64(47),
#    np.int64(44),
#    np.int64(44),
#    np.int64(47),
#    np.int64(41),
#    np.int64(41),
#    np.int64(62),
#    np.int64(49),
#    np.int64(62),
#    np.int64(44),
#    np.int64(49),
#    np.int64(44),
#    np.int64(51),
#    np.int64(54),
#    np.int64(57),
#    np.int64(57),
#    np.int64(53),
#    np.int64(55),
#    np.int64(58),
#    np.int64(55),
#    np.int64(48),
#    np.int64(54),
#    np.int64(62),
#    np.int64(47),
#    np.int64(49),
#    np.int64(53),
#    np.int64(48),
#    np.int64(47),
#    np.int64(41),
#    np.int64(43),
#    np.int64(60),
#    np.int64(48),
#    np.int64(51),
#    np.int64(55),
#    np.int64(60),
#    np.int64(60),
#    np.int64(42),
#    np.int64(51),
#    np.int64(55),
#    np.int64(55),
#    np.int64(60),
#    np.int64(58),
#    np.int64(57),
#    np.int64(51),
#    np.int64(51),
#    np.int64(43),
#    np.int64(55),
#    np.int64(42),
#    np.int64(54),
#    np.int64(58),
#    np.int64(62),
#    np.int64(42),
#    np.int64(41),
#    np.int64(62),
#    np.int64(55),
#    np.int64(58),
#    np.int64(42),
#    np.int64(54),
#    np.int64(54),
#    np.int64(55),
#    np.int64(43),
#    np.int64(47),
#    np.int64(58),
#    np.int64(54),
#    np.int64(48),
#    np.int64(47),
#    np.int64(42),
#    np.int64(44),
#    np.int64(44),
#    np.int64(54),
#    np.int64(51),
#    np.int64(42),
#    np.int64(53),
#    np.int64(53),
#    np.int64(55),
#    np.int64(58),
#    np.int64(56),
#    np.int64(56),
#    np.int64(55),
#    np.int64(48),
#    np.int64(44),
#    np.int64(42),
#    np.int64(44),
#    np.int64(51),
#    np.int64(43),
#    np.int64(49),
#    np.int64(43),
#    np.int64(53),
#    np.int64(62),
#    np.int64(54),
#    np.int64(57),
#    np.int64(58),
#    np.int64(56),
#    np.int64(56),
#    np.int64(41),
#    np.int64(47),
#    np.int64(55),
#    np.int64(56),
#    np.int64(56),
#    np.int64(49),
#    np.int64(44),
#    np.int64(62),
#    np.int64(48),
#    np.int64(53),
#    np.int64(55),
#    np.int64(47),
#    np.int64(62),
#    np.int64(54),
#    np.int64(41),
#    np.int64(47),
#    np.int64(57),
#    np.int64(60),
#    np.int64(54),
#    np.int64(55),
#    np.int64(42),
#    np.int64(42),
#    np.int64(54),
#    np.int64(51),
#    np.int64(56),
#    np.int64(62),
#    np.int64(56),
#    np.int64(51),
#    np.int64(47),
#    np.int64(58),
#    np.int64(54),
#    np.int64(48),
#    np.int64(43),
#    np.int64(53),
#    np.int64(58),
#    np.int64(53),
#    np.int64(62),
#    np.int64(49),
#    np.int64(42),
#    np.int64(51),
#    np.int64(62),
#    np.int64(51),
#    np.int64(48),
#    np.int64(49),
#    np.int64(58),
#    np.int64(41),
#    np.int64(53),
#    np.int64(41),
#    np.int64(53),
#    np.int64(43),
#    np.int64(47),
#    np.int64(51),
#    np.int64(44),
#    np.int64(58),
#    np.int64(57),
#    np.int64(43),
#    np.int64(49),
#    np.int64(43),
#    np.int64(44),
#    np.int64(42),
#    np.int64(44),
#    np.int64(48),
#    np.int64(51),
#    np.int64(48),
#    np.int64(58),
#    np.int64(48),
#    np.int64(57),
#    np.int64(57),
#    np.int64(41),
#    np.int64(41),
#    np.int64(60),
#    np.int64(55),
#    np.int64(60),
#    np.int64(43),
#    np.int64(47),
#    np.int64(47),
#    np.int64(57),
#    np.int64(56),
#    np.int64(62),
#    np.int64(55),
#    np.int64(60),
#    np.int64(55),
#    np.int64(58),
#    np.int64(49),
#    np.int64(55),
#    np.int64(51),
#    np.int64(42),
#    np.int64(48),
#    np.int64(62),
#    np.int64(49),
#    np.int64(48),
#    np.int64(62),
#    np.int64(42),
#    np.int64(54),
#    np.int64(43),
#    np.int64(43),
#    np.int64(44),
#    np.int64(58),
#    np.int64(43),
#    np.int64(60),
#    np.int64(58),
#    np.int64(55),
#    np.int64(51),
#    np.int64(53),
#    np.int64(58),
#    np.int64(48),
#    np.int64(57),
#    np.int64(56),
#    np.int64(47),
#    np.int64(56),
#    np.int64(43),
#    np.int64(60),
#    np.int64(62),
#    np.int64(42),
#    np.int64(51),
#    np.int64(60),
#    np.int64(49),
#    np.int64(51),
#    np.int64(54),
#    np.int64(60),
#    np.int64(58),
#    np.int64(51),
#    np.int64(54),
#    np.int64(48),
#    np.int64(55),
#    np.int64(42),
#    np.int64(55),
#    np.int64(55),
#    np.int64(57),
#    ...],
#   'index': [402,
#    985,
#    719,
#    1464,
#    536,
#    612,
#    14,
#    220,
#    1049,
#    1308,
#    1439,
#    192,
#    548,
#    1171,
#    1287,
#    145,
#    294,
#    1307,
#    686,
#    793,
#    792,
#    267,
#    1180,
#    415,
#    1183,
#    304,
#    1177,
#    1272,
#    904,
#    627,
#    539,
#    589,
#    863,
#    72,
#    1031,
#    1349,
#    710,
#    658,
#    1206,
#    196,
#    1036,
#    877,
#    1416,
#    282,
#    653,
#    1174,
#    780,
#    1328,
#    1389,
#    419,
#    480,
#    31,
#    27,
#    477,
#    777,
#    450,
#    1361,
#    194,
#    1283,
#    431,
#    98,
#    73,
#    802,
#    845,
#    1242,
#    508,
#    687,
#    1165,
#    503,
#    1438,
#    1383,
#    1276,
#    1312,
#    1290,
#    176,
#    528,
#    1303,
#    191,
#    1454,
#    1040,
#    1299,
#    171,
#    368,
#    419,
#    12,
#    1320,
#    899,
#    968,
#    17,
#    1218,
#    1297,
#    45,
#    1312,
#    455,
#    536,
#    1218,
#    647,
#    1325,
#    1250,
#    44,
#    1189,
#    192,
#    565,
#    355,
#    613,
#    1310,
#    79,
#    950,
#    898,
#    205,
#    1291,
#    1235,
#    238,
#    141,
#    505,
#    1325,
#    114,
#    499,
#    434,
#    737,
#    1354,
#    810,
#    977,
#    49,
#    1471,
#    423,
#    1456,
#    484,
#    1329,
#    1502,
#    662,
#    1479,
#    999,
#    517,
#    1085,
#    1428,
#    1342,
#    683,
#    1135,
#    540,
#    1094,
#    466,
#    738,
#    303,
#    653,
#    252,
#    835,
#    194,
#    635,
#    715,
#    401,
#    509,
#    51,
#    73,
#    938,
#    769,
#    813,
#    1098,
#    753,
#    51,
#    381,
#    291,
#    118,
#    828,
#    470,
#    1076,
#    373,
#    377,
#    778,
#    792,
#    255,
#    397,
#    1112,
#    793,
#    1362,
#    611,
#    504,
#    442,
#    89,
#    1310,
#    520,
#    918,
#    288,
#    538,
#    157,
#    593,
#    1134,
#    36,
#    806,
#    930,
#    803,
#    751,
#    674,
#    1250,
#    1349,
#    989,
#    366,
#    550,
#    196,
#    376,
#    1309,
#    783,
#    1437,
#    1114,
#    422,
#    1112,
#    1344,
#    570,
#    557,
#    1381,
#    776,
#    1336,
#    343,
#    1321,
#    550,
#    519,
#    56,
#    1405,
#    1057,
#    920,
#    609,
#    1343,
#    1413,
#    378,
#    90,
#    633,
#    1175,
#    674,
#    1211,
#    323,
#    1346,
#    92,
#    1153,
#    964,
#    1519,
#    298,
#    544,
#    1136,
#    83,
#    960,
#    182,
#    29,
#    1239,
#    1204,
#    97,
#    476,
#    1099,
#    1503,
#    669,
#    388,
#    1183,
#    477,
#    149,
#    591,
#    848,
#    1377,
#    179,
#    939,
#    262,
#    817,
#    928,
#    89,
#    723,
#    722,
#    580,
#    1061,
#    926,
#    1117,
#    449,
#    1440,
#    89,
#    597,
#    660,
#    1353,
#    375,
#    1311,
#    978,
#    68,
#    805,
#    216,
#    684,
#    1195,
#    391,
#    542,
#    1071,
#    310,
#    343,
#    739,
#    498,
#    1477,
#    360,
#    1308,
#    1065,
#    885,
#    1476,
#    1111,
#    1032,
#    963,
#    1029,
#    184,
#    596,
#    1241,
#    1270,
#    59,
#    10,
#    656,
#    1250,
#    1475,
#    1359,
#    630,
#    168,
#    1109,
#    215,
#    375,
#    505,
#    840,
#    1277,
#    198,
#    343,
#    363,
#    939,
#    926,
#    888,
#    1083,
#    895,
#    1303,
#    657,
#    1108,
#    1258,
#    206,
#    465,
#    763,
#    1031,
#    1005,
#    828,
#    386,
#    617,
#    930,
#    392,
#    1499,
#    1518,
#    1254,
#    768,
#    173,
#    948,
#    923,
#    1442,
#    396,
#    1122,
#    970,
#    301,
#    861,
#    674,
#    1452,
#    1206,
#    1106,
#    850,
#    24,
#    625,
#    53,
#    891,
#    496,
#    522,
#    65,
#    868,
#    1272,
#    1226,
#    63,
#    88,
#    1194,
#    1277,
#    362,
#    1208,
#    268,
#    595,
#    80,
#    1002,
#    1142,
#    611,
#    157,
#    1078,
#    321,
#    12,
#    158,
#    448,
#    1505,
#    1470,
#    775,
#    334,
#    1096,
#    873,
#    816,
#    934,
#    1496,
#    587,
#    480,
#    359,
#    914,
#    886,
#    188,
#    68,
#    645,
#    655,
#    1060,
#    1485,
#    222,
#    1257,
#    1072,
#    21,
#    1076,
#    75,
#    1278,
#    1258,
#    249,
#    844,
#    933,
#    480,
#    410,
#    347,
#    644,
#    1360,
#    988,
#    349,
#    1264,
#    1491,
#    1386,
#    1436,
#    368,
#    1063,
#    1329,
#    69,
#    237,
#    172,
#    254,
#    604,
#    805,
#    334,
#    1292,
#    123,
#    1409,
#    1122,
#    1336,
#    370,
#    348,
#    1514,
#    605,
#    1211,
#    289,
#    702,
#    1189,
#    642,
#    520,
#    879,
#    669,
#    761,
#    469,
#    1362,
#    1069,
#    1354,
#    256,
#    30,
#    1457,
#    660,
#    813,
#    348,
#    1200,
#    912,
#    1466,
#    328,
#    398,
#    343,
#    149,
#    1234,
#    502,
#    1403,
#    266,
#    1035,
#    127,
#    574,
#    1250,
#    968,
#    839,
#    121,
#    586,
#    594,
#    519,
#    971,
#    1464,
#    1197,
#    1000,
#    702,
#    1332,
#    884,
#    92,
#    1367,
#    1369,
#    484,
#    162,
#    50,
#    1200,
#    780,
#    38,
#    975,
#    357,
#    417,
#    270,
#    904,
#    1005,
#    584,
#    772,
#    26,
#    490,
#    746,
#    666,
#    659,
#    1232,
#    357,
#    960,
#    1494,
#    1172,
#    631,
#    787,
#    963,
#    740,
#    1296,
#    610,
#    1429,
#    16,
#    284,
#    968,
#    1352,
#    170,
#    418,
#    857,
#    84,
#    269,
#    701,
#    410,
#    755,
#    817,
#    8,
#    663,
#    595,
#    521,
#    686,
#    1320,
#    1426,
#    573,
#    205,
#    486,
#    439,
#    1294,
#    1136,
#    695,
#    538,
#    1117,
#    397,
#    1436,
#    966,
#    1139,
#    219,
#    641,
#    1504,
#    1383,
#    688,
#    146,
#    1343,
#    891,
#    61,
#    393,
#    666,
#    347,
#    1054,
#    768,
#    1357,
#    609,
#    31,
#    196,
#    193,
#    1518,
#    746,
#    795,
#    0,
#    362,
#    174,
#    162,
#    859,
#    65,
#    1087,
#    1200,
#    791,
#    125,
#    1466,
#    146,
#    215,
#    652,
#    1040,
#    1461,
#    703,
#    118,
#    1051,
#    1167,
#    698,
#    1046,
#    1388,
#    749,
#    417,
#    802,
#    1135,
#    1487,
#    1134,
#    122,
#    820,
#    542,
#    302,
#    230,
#    842,
#    695,
#    934,
#    284,
#    360,
#    1197,
#    1381,
#    109,
#    75,
#    1268,
#    54,
#    243,
#    839,
#    1094,
#    444,
#    254,
#    566,
#    1183,
#    1176,
#    496,
#    356,
#    255,
#    110,
#    1145,
#    181,
#    952,
#    1324,
#    17,
#    471,
#    875,
#    331,
#    1243,
#    1044,
#    468,
#    1246,
#    1377,
#    368,
#    589,
#    1197,
#    951,
#    430,
#    1220,
#    358,
#    1089,
#    105,
#    1322,
#    163,
#    670,
#    15,
#    1499,
#    635,
#    86,
#    898,
#    649,
#    323,
#    768,
#    779,
#    334,
#    1456,
#    1119,
#    975,
#    574,
#    93,
#    629,
#    1026,
#    918,
#    826,
#    910,
#    650,
#    1353,
#    1381,
#    6,
#    655,
#    89,
#    524,
#    1126,
#    979,
#    883,
#    76,
#    697,
#    863,
#    1065,
#    509,
#    1157,
#    1350,
#    1184,
#    644,
#    1400,
#    482,
#    308,
#    1066,
#    866,
#    1484,
#    1101,
#    381,
#    868,
#    243,
#    224,
#    907,
#    1405,
#    1179,
#    800,
#    816,
#    817,
#    172,
#    911,
#    122,
#    714,
#    38,
#    94,
#    1100,
#    1084,
#    228,
#    1072,
#    888,
#    176,
#    1129,
#    858,
#    872,
#    54,
#    1397,
#    1247,
#    1127,
#    1343,
#    20,
#    541,
#    1030,
#    1356,
#    539,
#    416,
#    557,
#    45,
#    308,
#    460,
#    988,
#    318,
#    1281,
#    106,
#    680,
#    1077,
#    108,
#    500,
#    203,
#    464,
#    832,
#    312,
#    497,
#    1067,
#    450,
#    731,
#    1015,
#    568,
#    326,
#    495,
#    1489,
#    1261,
#    1477,
#    1041,
#    30,
#    858,
#    833,
#    1018,
#    547,
#    1431,
#    1465,
#    298,
#    943,
#    1253,
#    606,
#    284,
#    1285,
#    240,
#    67,
#    436,
#    381,
#    1249,
#    417,
#    1383,
#    1425,
#    43,
#    591,
#    889,
#    960,
#    1356,
#    1375,
#    147,
#    1518,
#    733,
#    920,
#    257,
#    955,
#    1056,
#    247,
#    738,
#    552,
#    44,
#    1339,
#    1363,
#    1467,
#    718,
#    1463,
#    1335,
#    791,
#    864,
#    430,
#    1127,
#    548,
#    353,
#    571,
#    366,
#    1151,
#    183,
#    896,
#    1424,
#    953,
#    1332,
#    495,
#    682,
#    569,
#    571,
#    1335,
#    640,
#    881,
#    1314,
#    893,
#    333,
#    922,
#    1181,
#    1434,
#    351,
#    1286,
#    393,
#    699,
#    1145,
#    1025,
#    33,
#    210,
#    1367,
#    966,
#    771,
#    222,
#    744,
#    1229,
#    563,
#    636,
#    878,
#    740,
#    556,
#    554,
#    481,
#    1456,
#    1115,
#    627,
#    80,
#    1326,
#    342,
#    95,
#    123,
#    1350,
#    543,
#    1356,
#    266,
#    1412,
#    349,
#    766,
#    309,
#    311,
#    222,
#    472,
#    196,
#    785,
#    1059,
#    392,
#    735,
#    306,
#    79,
#    752,
#    837,
#    1323,
#    1307,
#    1185,
#    151,
#    1367,
#    246,
#    1419,
#    276,
#    137,
#    1491,
#    1002,
#    817,
#    1014,
#    657,
#    725,
#    439,
#    839,
#    970,
#    379,
#    433,
#    1002,
#    1477,
#    1455,
#    215,
#    228,
#    785,
#    933,
#    650,
#    999,
#    334,
#    371,
#    1208,
#    1143,
#    1092,
#    1006,
#    36,
#    134,
#    991,
#    1493,
#    534,
#    937,
#    956,
#    1259,
#    503,
#    788,
#    884,
#    1372,
#    1153,
#    983,
#    273,
#    571,
#    869,
#    816,
#    1073,
#    614,
#    465,
#    1357,
#    1049,
#    248,
#    697,
#    739,
#    78,
#    764,
#    272,
#    1275,
#    605,
#    299,
#    366,
#    646,
#    471,
#    1047,
#    404,
#    944,
#    294,
#    284,
#    1048,
#    747,
#    896,
#    1393,
#    1097,
#    354,
#    1038,
#    1292,
#    1097,
#    857,
#    1057,
#    1265,
#    467,
#    993,
#    1071,
#    600,
#    467,
#    42,
#    878,
#    1496,
#    818,
#    608,
#    916,
#    859,
#    1408,
#    462,
#    64,
#    1124,
#    734,
#    385,
#    688,
#    ...]})

# %% [markdown]
# ## Train 3 face labels

# %%
out = dataset_builder.build_train_test_datasets_from_concat_data(
    concat_data=concat_data,
    modality_keys=["lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    # y_labels=["gaze", "pupil"],
    y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", ],
    # y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", "gaze", "pupil"],
    sub_col="sub",
    modality_reduce_modes={
        "lfp_macro": "none",
        "lfp_micro": "none",
        "eye_gaze": "none",
        "pupil": "none",
    },
    sequence_label_configs={
        "gaze": {
            "seq_key": "eye_gaze",
            "reduce_mode": "mean",
        },
        "pupil": {
            "seq_key": "pupil",
            "reduce_mode": "last",
        },
    },
    numeric_label_configs=numeric_label_configs,
    test_ratio=0.2,
    batch_size=128,
    random_seed=42,
)

train_loader = out["train_loader"]
test_loader = out["test_loader"]

model = full_model.MultiModalFusionModel(
    modalities=["lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    n_temporal_layers=2,
    b_mod_early_fusion=False,
    d_encoder_dim=32,
    d_encoder_hidden=128,
    encoder_time_dilation=1,
    encoder_time_kernel=7,
    b_use_maxpooling_layer=True,
    sequential_model_hidden=64,
    sequential_model_type="transformer",
    sequential_model_layers=1,
    sequential_pooling="mean",
    dropout=0.1,
    outhead="fcl",
    label_dim=3,
)

cfg = Trainer.TrainConfig(
    epochs=300,
    batch_size=128,
    lr=3e-4,
    save_path="best_model.pt",
    y_order=["emo_neutral", "jacky_ratio", "front_face_ratio"],
    # y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", "gaze", "pupil"],
)

history, best_path = Trainer.run_training_with_loaders(
    model,
    train_loader,
    test_loader,
    cfg,
    loss="smooth_l1",
    device="cpu",
)

print("best saved to:", best_path)

eval_metrics, out = metrics.evaluate_model(
    model,
    test_loader,
    y_order=["front_face_ratio"],
    device="cpu",
)
# Out:
# Epoch 001/300 | lr 3.00e-04 | train loss 0.158868 | val loss 0.135810 | best 0.135810 (ep 001) | es 0/20 | improved
# Epoch 002/300 | lr 3.00e-04 | train loss 0.139935 | val loss 0.137609 | best 0.135810 (ep 001) | es 1/20
# Epoch 003/300 | lr 3.00e-04 | train loss 0.139201 | val loss 0.137234 | best 0.135810 (ep 001) | es 2/20
# Epoch 004/300 | lr 3.00e-04 | train loss 0.138588 | val loss 0.140120 | best 0.135810 (ep 001) | es 3/20
# Epoch 005/300 | lr 3.00e-04 | train loss 0.138149 | val loss 0.141922 | best 0.135810 (ep 001) | es 4/20 | lr-> 1.50e-04
# Epoch 006/300 | lr 1.50e-04 | train loss 0.137601 | val loss 0.148820 | best 0.135810 (ep 001) | es 5/20
# Epoch 007/300 | lr 1.50e-04 | train loss 0.137372 | val loss 0.145622 | best 0.135810 (ep 001) | es 6/20
# Epoch 008/300 | lr 1.50e-04 | train loss 0.137051 | val loss 0.148925 | best 0.135810 (ep 001) | es 7/20
# Epoch 009/300 | lr 1.50e-04 | train loss 0.136929 | val loss 0.145424 | best 0.135810 (ep 001) | es 8/20 | lr-> 7.50e-05
# Epoch 010/300 | lr 7.50e-05 | train loss 0.136649 | val loss 0.146117 | best 0.135810 (ep 001) | es 9/20
# Epoch 011/300 | lr 7.50e-05 | train loss 0.136729 | val loss 0.147536 | best 0.135810 (ep 001) | es 10/20
# Epoch 012/300 | lr 7.50e-05 | train loss 0.136651 | val loss 0.147154 | best 0.135810 (ep 001) | es 11/20
# Epoch 013/300 | lr 7.50e-05 | train loss 0.136770 | val loss 0.145021 | best 0.135810 (ep 001) | es 12/20 | lr-> 3.75e-05
# Epoch 014/300 | lr 3.75e-05 | train loss 0.136555 | val loss 0.147617 | best 0.135810 (ep 001) | es 13/20
# Epoch 015/300 | lr 3.75e-05 | train loss 0.136515 | val loss 0.147307 | best 0.135810 (ep 001) | es 14/20
# Epoch 016/300 | lr 3.75e-05 | train loss 0.136573 | val loss 0.148759 | best 0.135810 (ep 001) | es 15/20
# Epoch 017/300 | lr 3.75e-05 | train loss 0.136405 | val loss 0.147786 | best 0.135810 (ep 001) | es 16/20 | lr-> 1.87e-05
# Epoch 018/300 | lr 1.87e-05 | train loss 0.136468 | val loss 0.149249 | best 0.135810 (ep 001) | es 17/20
# Epoch 019/300 | lr 1.87e-05 | train loss 0.136376 | val loss 0.149262 | best 0.135810 (ep 001) | es 18/20
# Epoch 020/300 | lr 1.87e-05 | train loss 0.136280 | val loss 0.149848 | best 0.135810 (ep 001) | es 19/20
# Epoch 021/300 | lr 1.87e-05 | train loss 0.136324 | val loss 0.149665 | best 0.135810 (ep 001) | es 20/20 | lr-> 9.37e-06
# Early stopping triggered at epoch 21. Best epoch = 1.
# Loaded best model from epoch 1 with val loss 0.13581037286080813
# best saved to: best_model.pt

# %%
eval_metrics, out = metrics.evaluate_model(
    model,
    test_loader,
    y_order=["emo_neutral", "jacky_ratio", "front_face_ratio"],
    device="cpu",
)
# Out:
# === Test metrics ===
#
# emo_neutral
#   mae: 0.173290
#   mse: 0.102839
#   rmse: 0.320686
#   r2: -0.018284
#
# jacky_ratio
#   mae: 0.295438
#   mse: 0.164717
#   rmse: 0.405853
#   r2: -0.020765
#
# front_face_ratio
#   mae: 0.383099
#   mse: 0.201249
#   rmse: 0.448608
#   r2: -0.025142

# %% [markdown]
# ## Train with one-label

# %%
out = dataset_builder.build_train_test_datasets_from_concat_data(
    concat_data=concat_data,
    modality_keys=["lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    # y_labels=["gaze", "pupil"],
    y_labels=["front_face_ratio", ],
    # y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", "gaze", "pupil"],
    sub_col="sub",
    modality_reduce_modes={
        "lfp_macro": "none",
        "lfp_micro": "none",
        "eye_gaze": "none",
        "pupil": "none",
    },
    sequence_label_configs={
        "gaze": {
            "seq_key": "eye_gaze",
            "reduce_mode": "mean",
        },
        "pupil": {
            "seq_key": "pupil",
            "reduce_mode": "last",
        },
    },
    numeric_label_configs=numeric_label_configs,
    test_ratio=0.2,
    batch_size=128,
    random_seed=42,
)

train_loader = out["train_loader"]
test_loader = out["test_loader"]

model = full_model.MultiModalFusionModel(
    modalities=["lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    n_temporal_layers=2,
    b_mod_early_fusion=False,
    d_encoder_dim=32,
    d_encoder_hidden=128,
    encoder_time_dilation=1,
    encoder_time_kernel=7,
    b_use_maxpooling_layer=True,
    sequential_model_hidden=64,
    sequential_model_type="transformer",
    sequential_model_layers=1,
    sequential_pooling="attn",
    dropout=0.1,
    outhead="fcl",
    label_dim=1,
)

cfg = Trainer.TrainConfig(
    epochs=300,
    batch_size=128,
    lr=3e-4,
    save_path="best_model.pt",
    y_order=["front_face_ratio"],
    early_stop_patience=10,
    # y_labels=["emo_neutral", "jacky_ratio", "front_face_ratio", "gaze", "pupil"],
)

history, best_path = Trainer.run_training_with_loaders(
    model,
    train_loader,
    test_loader,
    cfg,
    loss="smooth_l1",
    device="cpu",
)

print("best saved to:", best_path)

eval_metrics, out = metrics.evaluate_model(
    model,
    test_loader,
    y_order=["front_face_ratio"],
    device="cpu",
)
# Out:
# Epoch 001/300 | lr 3.00e-04 | train loss 0.185451 | val loss 0.183477 | best 0.183477 (ep 001) | es 0/10 | improved
# Epoch 002/300 | lr 3.00e-04 | train loss 0.184315 | val loss 0.183470 | best 0.183477 (ep 001) | es 1/10
# Epoch 003/300 | lr 3.00e-04 | train loss 0.183803 | val loss 0.184762 | best 0.183477 (ep 001) | es 2/10
# Epoch 004/300 | lr 3.00e-04 | train loss 0.183467 | val loss 0.186801 | best 0.183477 (ep 001) | es 3/10
# Epoch 005/300 | lr 3.00e-04 | train loss 0.182931 | val loss 0.189393 | best 0.183477 (ep 001) | es 4/10 | lr-> 1.50e-04
# Epoch 006/300 | lr 1.50e-04 | train loss 0.182490 | val loss 0.195732 | best 0.183477 (ep 001) | es 5/10
# Epoch 007/300 | lr 1.50e-04 | train loss 0.182590 | val loss 0.197558 | best 0.183477 (ep 001) | es 6/10
# Epoch 008/300 | lr 1.50e-04 | train loss 0.181922 | val loss 0.194106 | best 0.183477 (ep 001) | es 7/10
# Epoch 009/300 | lr 1.50e-04 | train loss 0.182049 | val loss 0.204612 | best 0.183477 (ep 001) | es 8/10 | lr-> 7.50e-05
# Epoch 010/300 | lr 7.50e-05 | train loss 0.181752 | val loss 0.206230 | best 0.183477 (ep 001) | es 9/10
# Epoch 011/300 | lr 7.50e-05 | train loss 0.181710 | val loss 0.200623 | best 0.183477 (ep 001) | es 10/10
# Early stopping triggered at epoch 11. Best epoch = 1.
# Loaded best model from epoch 1 with val loss 0.18347705077183873
# best saved to: best_model.pt
# === Test metrics ===
#
# front_face_ratio
#   mae: 0.384244
#   mse: 0.200404
#   rmse: 0.447666
#   r2: -0.020842
